# %% [markdown]
# # ¡Hola Constanza! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# ------

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Constanza completaste todas las tareas propuestas para el proyecto de manera sobresaliente. Demostraste un excelente manejo de las herramientas de manipulación y visualización de datos.
#
# Como sugerencia para fortalecer aún más tu análisis estadístico, sería conveniente incorporar la prueba de Levene antes de realizar comparaciones de medias, ya que esto asegurará que tus resultados sean más robustos y confiables.
#
# Continúa desarrollando estas habilidades, ya que serán claves en futuros proyectos.
#
# Éxitos en tu próximo sprint 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# -----

# %% [markdown]
# # PROYECTO SPRINT 8

# %% [markdown]
# ## Descripción del Proyecto

# %% [markdown]
# Estás trabajando como analista para Zuber, una nueva empresa de viajes compartidos que se está lanzando en Chicago. Tu tarea es encontrar patrones en la información disponible. Quieres comprender las preferencias de los pasajeros y el impacto de los factores externos en los viajes.
# Al trabajar con una base de datos, analizarás los datos de los competidores y probarás una hipótesis sobre el impacto del clima en la frecuencia de los viajes.

# %% [markdown]
# ## Descripción de los datos

# %% [markdown]
# Una base de datos con información sobre viajes en taxi en Chicago:
#
# 1. tabla neighborhoods : datos sobre los barrios de la ciudad
# - name : nombre del barrio
# - neighborhood_id : código del barrio
#
# 2. tabla cabs : datos sobre los taxis
# - cab_id : código del vehículo
# - vehicle_id : ID técnico del vehículo
# - company_name : la empresa propietaria del vehículo
#
# 3. tabla trips : datos sobre los viajes
# - trip_id : código del viaje
# - cab_id : código del vehículo que opera el viaje
# - start_ts : fecha y hora de inicio del viaje (tiempo redondeado a la hora)
# - end_ts : fecha y hora de finalización del viaje (tiempo redondeado a la hora)
# - duration_seconds : duración del viaje en segundos
# - distance_miles : distancia del viaje en millas
# - pickup_location_id : código del barrio de recogida
# - dropoff_location_id : código del barrio de finalización del recorrido
#
# 4. tabla weather_records : datos sobre el clima
# - record_id : código del registro meteorológico
# - ts : fecha y hora del registro (tiempo redondeado a la hora)
# - temperature : temperatura cuando se tomó el registro
# - description : breve descripción de las condiciones meteorológicas, por ejemplo,
# - "lluvia ligera" o "nubes dispersas"

# %% [markdown]
# ## Esquema de tabla ER

# %% [markdown]
# ![image.png](attachment:31cd226e-21d5-4625-b8e6-6efac50aa403.png)

# %% [markdown]
# Nota: no existe una conexión directa entre las tablas trips y weather_records en la base de datos. Pero aún puedes usar JOIN y vincularlas usando la hora en la que comenzó el viaje ( trips.start_ts ) y la hora en la que se tomó el registro meteorológico ( weather_records.ts ).

# %% [markdown]
# ## Instrucciones para completar el proyecto

# %% [markdown]
# ### **Paso 1**. Escribe un código para analizar los datos sobre el clima en Chicago en noviembre de 2017 desde el sitio web:

# %% [markdown]
# http://slava-public-access.s3-website-eu-west-1.amazonaws.com
#
#
# https://s3-us-west-2.amazonaws.com/secure.notion-static.com/d752cb24-f5ed-4 b1c-b6a4-570fbc905b7c/chicago_weather_2017.html

# %% [markdown]
# **NOTA.** Este Paso 1 se desarrollo en el los ejercicios previos a este Jupyter Notebook.

# %% [markdown]
# De este Paso 1, se obtuvo una tabla 'weather_records' que contiene tres columnas Date and Time, Temperature y Description con 697 líneas. En esta tabla se encuentra un reporte diario del estado del clima en la ciudad de Chicago, el reporte para cada hora del día durante el mes de noviembre de 2017. En la descripción se puede ver las condiciones meteorológicas, para la hora de la toma del registro es nubes dispersas, alta densidad de nubes, cielo despejado, neblina o los diferentes estados de lluvia. Adicionalmente se presenta la temperatura en la hora del registro.

# %% [markdown]
# ### **Paso 2**. Análisis exploratorio de datos

# %% [markdown]
# 1. Encuentra el número de viajes en taxi para cada empresa de taxis del 15 al 16 de noviembre de 2017. Nombra el campo resultante trips_amount y muéstralo junto con el campo company_name. Ordena los resultados por el campo trips_amount en
# orden descendente.
#
# 2. Encuentra la cantidad de viajes para cada empresa de taxis cuyo nombre contenga las palabras "Yellow" o "Blue" del 1 al 7 de noviembre de 2017. Nombra la variable resultante trips_amount. Agrupa los resultados por el campo company_name.
#
# 3. En noviembre de 2017 las empresas de taxis más populares fueron Flash Cab y Taxi Affiliation Services. Encuentra el número de viajes de estas dos empresas y nombra la variable resultante trips_amount . Junta los viajes de todas las demás
# empresas en el grupo "Other". Agrupa los datos por nombres de empresas de taxis. Nombra el campo con nombres de empresas de taxis company. Ordena el resultado en orden descendente por trips_amount.

# %% [markdown]
# **NOTA.** Este Paso 2 se desarrollo en el los ejercicios previos a este Jupyter Notebook.

# %% [markdown]
# En este paso exploratorio de los datos se obtuvo la siguiente información:
#
# 1. De la tabla 'cabs', se obtuvo información sobre los datos de taxis como el nombre de la compañía de taxis 'company_name' y el promedio de viajes para cada compañía 'trips_amount' entre los días 15 y 16 de noviembre de 2017. Esta tabla cuenta con 64 filas.
#
# 2. De la misma tabla 'cabs', se obtuvieron las compañías con la condición de tener las palabras Yellow o Blue en sus nombres, para los días del 1 al 7 de noviembre de 2017. Se obtuvo una tabla con 4 filas, el nombre de las compañías y el promedio de viaje para los días de esta condición. El nombre de las compañías encontradas son Taxi Affiliation Service Yellow, Yellow Cab, Blue Diamond, Blue Ribbon Taxi Association Inc. Siendo Yellow Cab la empresesa de taxis que más registró viajes para estos días.
#
# 3. En este punto se obtuvo el promedio de viajes para las dos compañías más populares así como la cantidad de viajes de las demás compañías. Las otras empresas, tuvieron un total de 335771 viajes, Flash Cab 64084 viajes y Taxi Affiliation Services 37583 viajes, para los días 1 al 7 de noviembre del 2017.

# %% [markdown]
# ### **Paso 3**. Prueba la hipótesis de que la duración de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos.

# %% [markdown]
# 4. Recupera los identificadores de los barrios de O'Hare y Loop de la tabla neighborhoods.
#
# 5. Para cada hora recupera los registros de condiciones meteorológicas de la tabla weather_records . Usando el operador CASE, divide todas las horas en dos grupos: "Bad" si el campo description contiene las palabras "rain" o "storm" y "Good" para los demás. Nombra el campo resultante weather_conditions . La tabla final debe incluir dos campos: fecha y hora (ts) y weather_conditions.
#
# 6. Recupera de la tabla trips todos los viajes que comenzaron en el Loop (neighborhood_id : 50) y finalizaron en O'Hare (neighborhood_id : 63) un sábado. Obtén las condiciones climáticas para cada viaje. Utiliza el método que aplicaste en la tarea anterior. Recupera también la duración de cada viaje. Ignora los viajes para los que no hay datos disponibles sobre las condiciones climáticas.

# %% [markdown]
# Para probar esta hipótesis, se recuperan los los siguientes datos:
#
# 4. En esta sección, de la tabla 'neighborhoods' se extraen los identificadores de los barrios O'Hare y Loop para continuar con la recopilación de datos necesaria para la realización de la prueba de Hipótesis. Los neighborhood_id obtenidos para O'Hare y Loop son 50 y 63 respectivamente.
#
# 5. De la tabla 'weather_records', se obtuvo la información sobre las condiciones climáticas, contiene dos columnas una ts que contiene hora y fecha de la toma de registro y weather_conditions que indica si es Good (para días no lluviosos) y Bad (para los días que contienen en description rain o storm). Se obtuvieron 697 líneas.
#
# 6. En esta parte de extracción de información, se obtuvo una tabla con tres columnas: 'start_ts', 'weather_conditions' y	'duration_seconds', correspondiendo a los datos de la hora y fecha de la toma del inicio del viaje, la duración del viaje de la tabla 'trips' y la condición metereológica en el momento del viaje de la tabla 'weather_records'.

# %% [markdown]
# **NOTA.** Este Paso 3 se desarrollo en el los ejercicios previos a este Jupyter Notebook.

# %% [markdown]
# ### **Paso 4**. Análisis exploratorio de datos (Python)

# %% [markdown]
# Además de los datos que recuperaste en las tareas anteriores te han dado un segundo archivo. Ahora tienes estos dos CSV:
#
# 1. tabla project_sql_result_01.csv . Contiene los siguientes datos:
# - company_name : nombre de la empresa de taxis
# - trips_amount : el número de viajes de cada compañía de taxis el 15 y 16 de noviembre de 2017.
#
# 2. tabla project_sql_result_04.csv. Contiene los siguientes datos:
# - dropoff_location_name : barrios de Chicago donde finalizaron los viajes
# - average_trips : el promedio de viajes que terminaron en cada barrio en noviembre de 2017.
#
# Para estos dos datasets ahora necesitas:

# %% [markdown]
# #### **4.1. Importar los archivos**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from math import factorial
from scipy import stats as st
from matplotlib import pyplot as plt

# %%
taxis = pd.read_csv('/datasets/project_sql_result_01.csv')

# %%
neighborhoods = pd.read_csv('/datasets/project_sql_result_04.csv')

# %% [markdown]
# #### **4.2. Estudiar los datos que contienen**

# %% [markdown]
# ##### 4.2.1. Analisis de datos de taxis

# %%
taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  64 non-null     object
#  1   trips_amount  64 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
taxis.tail(20)
# Out:
#                           company_name  trips_amount
# 44          2092 - 61288 Sbeih Company            27
# 45           3011 - 66308 JBL Cab Inc.            25
# 46     3620 - 52292 David K. Cab Corp.            21
# 47       4615 - 83503 Tyrone Henderson            21
# 48  3623 - 72222 Arrington Enterprises            20
# 49              5074 - 54002 Ahzmi Inc            16
# 50        2823 - 73307 Lee Express Inc            15
# 51                4623 - 27290 Jay Kim            15
# 52           3721 - Santamaria Express            14
# 53            5006 - 39261 Salifu Bawa            14
# 54           2192 - 73487 Zeymane Corp            14
# 55           6057 - 24657 Richard Addo            13
# 56       5997 - 65283 AW Services Inc.            12
# 57                         Metro Group            11
# 58             5062 - 34841 Sam Mestas             8
# 59        4053 - 40193 Adwar H. Nikola             7
# 60             2733 - 74600 Benny Jona             7
# ...

# %% [markdown]
# El DatafFrame que contiene la información de la empresa de taxis y la cantidad de viajes que realizó entre el 15 y 16 de noviembre de 2017 lo nombré 'taxis'.
#
# Observando la información de este DataFrame presentada por función info( ) se confirma que está compuesto por dos columnas  company_name y trips_amount, ambas con 64 valores non-null, indicando que no hay valores ausentes.
#
# En cuanto al tipo de datos, para la columna company_name correspondiente a los nombres de la empresa de taxis son tipo 'object', mientras que para la columna trips_amount correspondiente al número de viajes para cada compañía, los tipos de datos son 'int64' por ser tados numéricos. En ambas columnas, los tipos de datos son los correctos de acuerdo a la información suministrada en cada columna.

# %% [markdown]
# ##### 4.2.2. Análisis de datos de neighborhoods

# %%
neighborhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dropoff_location_name  94 non-null     object
#  1   average_trips          94 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.6+ KB

# %%
neighborhoods.head()
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000

# %% [markdown]
# El DatafFrame que contiene la información de los barrios y el promedio de los de viajes que terminaron en cada barrio en noviembre de 2017 lo nombré 'neighborhoods'.
#
# Observando la información de este DataFrame presentada por función info( ) se confirma que está compuesto por dos columnas  dropoff_location_name y average_trips, ambas con 94 valores non-null, indicando que no hay valores ausentes.
#
# En cuanto al tipo de datos, para la columna dropoff_location_name correspondiente a los nombres de los barrios donde finalizan los viajes son tipo 'object', mientras que para la columna average_trips correspondiente al promedio de viajes que terminanron en cada barrio, los tipos de datos son 'float64'. En ambas columnas los tipos de datos son los correctos de acuerdo a la información suministrada de cada columna.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo importando las librerías y los datos del proyecto. Adicionalmente usaste correctamente las funciones `info`, `tail` y `head`, esto te permite hacer una primera revisión de los datos, su estructura y contenido. Con esta información, podemos establecer una hoja de ruta para ajustar, modificar y analizar los datos de una manera adecuada.
#
# </div>

# %% [markdown]
# #### **4.3. Identificar los 10 principales barrios en términos de finalización del recorrido**

# %%
top_10_dropoff_location = neighborhoods.sort_values(by='average_trips', ascending=False).head(10)

top_10_dropoff_location
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000
# 5             Lake View    2420.966667
# 6            Grant Park    2068.533333
# 7         Museum Campus    1510.000000
# 8            Gold Coast    1364.233333
# 9    Sheffield & DePaul    1259.766667

# %% [markdown]
# Los 10 barrios principales en términos de finalización del recorrido para el mes de noviembre de 2017 de acuerdo al promedio de viajes, se muestran en el DataFrame top_10_location. En estos barrios se pueden encontrar zonas de interés común como el centro de la ciudad, zona de bares y restaurantes, tiendas de moda, lugares turísticos y hoteles. Es muy posible que a esto se deba el promedio de viajes para visitar estos lugares de interés.

# %% [markdown]
# #### **4.4. Hacer gráficos: empresas de taxis y número de viajes, los 10 barrios principales por número de finalizaciones**

# %% [markdown]
# #### 4.4.1. Gráfico de empresas de taxis y número de viajes

# %%
plt.figure(figsize=(12, 10))

taxis_sorted = taxis.sort_values(by='trips_amount', ascending=False)

plt.bar(taxis_sorted['company_name'], taxis_sorted['trips_amount'], color='gold', edgecolor='black')
plt.title('Número de viajes por compañía de taxis entre los días 15 y 16 de noviembre de 2017')
plt.xlabel('Compañía de taxis')
plt.ylabel('Número de viajes')
plt.xticks(rotation=90, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %% [markdown]
# De acuerdo a la gráfica anterior se observa que las tres compañías de taxis más populares de la ciudad de Chicago son, en primer lugar la compañía 'Flash Cab' con aproximadamente 19.000 viajes, seguida por 'Taxi Affiliation Services' con 11.500 viajes, en tercer lugar 'Medallion Leasing' alrededor de 10.500 viajes para los días 15 y 16 de noviembre de 2017. Las compañías de taxis que les siguen reportarón menos de 10.000 viajes como 'Yellow Cab', 'Taxi Affiliation Sarvice Yellow' y 'Chicago Carriage Cab Club' con un aproximado para estas compañías de 8.000 a 9.000 viajes.
#
# Hay compañías que presentan tan pocos viajes, que no alcanzan a salir en la gráfica. Observando los datos del DataFrame 'taxis', reportan menos de 100 viajes en esos días, incluso compañías como 'Metro Group' o 'Andrews Cab' presentan menos de 10 viajes para estos dos días. Esto indica que son compañías muy pequeñas que apenas están abriéndose un campo en estos servicios de transporte o que son empresas que tienden a desaparecer.
#
# En conclusión, la compañía preferida por los usuarios en la ciudad de Chicago es 'Flash Cab' debido a que casi duplica en cantidad de viajes la compañía que se encunetra posicionada como la seunda en la que más confian los usuarios 'Taxi Affiliation Services'.

# %% [markdown]
# Utilicé el gráfico de barras porque me permite comparar fácilmente categorías como la cantidad de viajes entre diferentes empresas de taxis. Además, pesenta con mayor claridad las compañías que tuvieron más viajes y las que casi no tuvieron viajes.
# Adicionalmente, se pueden ver las empresas más dominantes del mercado.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu análisis comunica de forma clara cómo se distribuyen los viajes entre las distintas compañías de taxis, resaltando bien la diferencia en volumen entre las principales empresas y aquellas con baja actividad. Es positivo que hayas interpretado el bajo número de viajes como una posible señal de empresas en crecimiento o en declive, lo que agrega una dimensión más estratégica a tu observación.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Como recomendación, puedes configurar la gráfica para solo mostrar el Top 10 de empresas, ya que si te das cuenta más de la mitad de empresas tienen muy pocos datos. Esto le dará claridad a la información y facilitará su interpretación.
#
# </div>
# </div>

# %% [markdown]
# #### 4.4.2. Gráfico de los 10 barrios principales por número de finalizaciones de viajes

# %%
plt.figure(figsize=(10, 8))

plt.bar(top_10_dropoff_location['dropoff_location_name'], top_10_dropoff_location['average_trips'], color='steelblue', edgecolor='black')
plt.title('Barrios con mayor finalización de viajes en el mes de noviembre de 2017 en Chicago')
plt.xlabel('Barrios de Chicago')
plt.ylabel('Promedio de finalización de viajes')
plt.xticks(rotation=90, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %% [markdown]
# Analizando la gráfica de barras de los barrios de Chicago con mayor promedio de finalización de viajes para noviembre de 2017, se observa que el sector con mayor concurrencia de pasajeros es el central barrio de 'Loop' con casi 11.000 finalizaciones de viaje, este sector es reconocido por ser el distrito financiero, tener edificios emblemáticos, atracciones culturales y zonas turísticas. El barrio 'River North' (9.500 finalizaciones) que ocupa el segundo lugar de este top 10, se destaca por tener un ambiente animado, vida nocturna, galerías de arte y restaurantes, además tiene más zona residencial en comparación a 'Loop'. En el tercer y cuarto lugar de los 10 barrios de Chicago con mayor finalización de viajes se encuentran 'Streeterville' conocido por su ambiente urbano, rascacielos residenciales, hoteles de lujo y tiendas exclusivas; mientras que 'West Loop', se destaca por su oferta gastronómica, galerías de arte y boutiques, con 6.600 y 5.100 finalizaciones de viaje respectivamente.
#
# Esto indica que las zonas centro, con lugares de interés turísticos, financieros, con galerías de arte, boutiques, zonas exclusivas y de lujo, hoteles y amplia oferta gastronomía de restaurantes y bares fueron las zonas más visitadas de Chicago para el mes de noviembre de 2017 y probablemente las más importantes y tradicionalmente visitadas en esta ciudad.
#
# Los otros barrios de interés de este top 10 con mayores finalizaciones de todos los barrios de Chicago, presentan un promedio entre 1.200 y 2.500. Aunque son barrios que también cuentan con actividades culturales, zonas turísticas, de negocios, oferta gastronómica, vida nocturna y lugares importantes, son mucho menos concurridos que los barrios que ocupan los primero cuatro puestos de esta lista de 10.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu interpretación muestra una muy buena integración entre los datos presentados y el contexto urbano de Chicago, lo cual enriquece el análisis y permite comprender por qué ciertos barrios concentran mayor número de viajes. Es acertado cómo conectas la infraestructura cultural, turística y económica con la alta demanda de transporte en zonas como Loop y River North, lo que demuestra una lectura que va más allá de los números.
#
# </div>

# %% [markdown]
# ### **Paso 5**. Prueba de Hopótesis (Python)

# %% [markdown]
# /datasets/project_sql_result_07.csv — el resultado de la última consulta. Contiene datos sobre viajes desde el Loop hasta el Aeropuerto Internacional O'Hare. Recuerda, estos son los valores de campo de la tabla:
#
# - start_ts: fecha y hora de la recogida
# - weather_conditions: condiciones climáticas en el momento en el que comenzó el viaje
# - duration_seconds: duración del viaje en segundos
#
# Prueba la hipótesis:
# "La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos".
#
# Decide por tu cuenta dónde establecer el nivel de significación (alfa).
#
# Explica:
# - Cómo planteaste las hipótesis nula y alternativa.
# - Qué criterio usaste para probar las hipótesis y por qué.

# %% [markdown]
# #### **5.1. Cargar el DataFrame de viajes de 'Loop' al 'Aeropuerto Internacional O'Hare'**

# %%
trips_loop_ohare = pd.read_csv('/datasets/project_sql_result_07.csv')

# %% [markdown]
# #### **5.2. Analizar la información del DataFrame de viajes de 'Loop' al 'Aeropuerto Internacional O'Hare'**

# %%
trips_loop_ohare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   object
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 25.2+ KB

# %%
trips_loop_ohare.sample(10)
# Out:
#                  start_ts weather_conditions  duration_seconds
# 27    2017-11-11 12:00:00               Good            2289.0
# 1000  2017-11-18 08:00:00                Bad            1200.0
# 271   2017-11-18 12:00:00                Bad            2700.0
# 137   2017-11-18 13:00:00                Bad            3300.0
# 790   2017-11-04 15:00:00               Good            3180.0
# 32    2017-11-11 10:00:00               Good            1506.0
# 235   2017-11-04 05:00:00               Good            1217.0
# 109   2017-11-11 04:00:00               Good            1213.0
# 977   2017-11-11 12:00:00               Good            1680.0
# 439   2017-11-11 14:00:00               Good            2100.0

# %% [markdown]
# Observando la tabla de los viajes del barrio 'Loop' en el centro hasta el 'Aeropuerto Internacional O'Hare', se encuentra que las tres columnas tienen la misma cantidad de valores 'non-null', por lo tanto se puede concluir que no presenta valores ausentes. Además se encuentra con respecto a los tipos de datos, que la columna 'start_ts' es tipo oject, pero debería ser datetime por corresponder a valores de fecha y hora. La columna 'weather_condictions' tiene el tipo de datos adecuado porque al ser un string, el tipo object es el correcto. En cuanto a la columna 'duration_seconds' al tener datos numéricos, el tipo float64 es el adecuado para esta columna.

# %% [markdown]
# #### **5.3. Convertir los datos de 'start_ts' al tipo de datos de datetime y extraer el día sábado**

# %% [markdown]
# ##### 5.3.1. Convertir los datos de 'start_ts' al tipo de datos de datetime

# %%
trips_loop_ohare['start_ts'] = pd.to_datetime(trips_loop_ohare['start_ts'])

trips_loop_ohare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   datetime64[ns]
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 25.2+ KB

# %% [markdown]
# ##### 5.3.2. Extraer el día sábado de la columna 'start_ts'

# %%
trips_loop_ohare['day_of_week'] = trips_loop_ohare['start_ts'].dt.dayofweek

saturday_trips = trips_loop_ohare[trips_loop_ohare['day_of_week'] == 5]

saturday_trips.head(10)
# Out:
#              start_ts weather_conditions  duration_seconds  day_of_week
# 0 2017-11-25 16:00:00               Good            2410.0            5
# 1 2017-11-25 14:00:00               Good            1920.0            5
# 2 2017-11-25 12:00:00               Good            1543.0            5
# 3 2017-11-04 10:00:00               Good            2512.0            5
# 4 2017-11-11 07:00:00               Good            1440.0            5
# 5 2017-11-11 04:00:00               Good            1320.0            5
# 6 2017-11-04 16:00:00                Bad            2969.0            5
# 7 2017-11-18 11:00:00               Good            2280.0            5
# 8 2017-11-11 14:00:00               Good            2460.0            5
# 9 2017-11-11 12:00:00               Good            2040.0            5

# %% [markdown]
# #### **5.4. Tiempo lluvioso y no lluvioso en día sábado del mes de noviembre de 2017**

# %%
# Sábados lluviosos de noviembre de 2017

rainy_saturday_trips = saturday_trips[saturday_trips['weather_conditions'] == 'Bad']

rainy_saturday_trips
# Out:
#                 start_ts weather_conditions  duration_seconds  day_of_week
# 6    2017-11-04 16:00:00                Bad            2969.0            5
# 30   2017-11-18 12:00:00                Bad            1980.0            5
# 34   2017-11-04 17:00:00                Bad            2460.0            5
# 51   2017-11-04 16:00:00                Bad            2760.0            5
# 52   2017-11-18 12:00:00                Bad            2460.0            5
# ...                  ...                ...               ...          ...
# 1031 2017-11-18 12:00:00                Bad            2560.0            5
# 1032 2017-11-18 10:00:00                Bad            1908.0            5
# 1053 2017-11-18 12:00:00                Bad            2400.0            5
# 1061 2017-11-18 16:00:00                Bad            2186.0            5
# 1067 2017-11-04 16:00:00                Bad            2834.0            5
#
# [180 rows x 4 columns]

# %%
# Sábados no lluviosos de noviembre de 2017

good_saturday_trips = saturday_trips[saturday_trips['weather_conditions'] == 'Good'] 

good_saturday_trips
# Out:
#                 start_ts weather_conditions  duration_seconds  day_of_week
# 0    2017-11-25 16:00:00               Good            2410.0            5
# 1    2017-11-25 14:00:00               Good            1920.0            5
# 2    2017-11-25 12:00:00               Good            1543.0            5
# 3    2017-11-04 10:00:00               Good            2512.0            5
# 4    2017-11-11 07:00:00               Good            1440.0            5
# ...                  ...                ...               ...          ...
# 1062 2017-11-11 06:00:00               Good            1500.0            5
# 1063 2017-11-25 11:00:00               Good               0.0            5
# 1064 2017-11-11 10:00:00               Good            1318.0            5
# 1065 2017-11-11 13:00:00               Good            2100.0            5
# 1066 2017-11-11 08:00:00               Good            1380.0            5
#
# [888 rows x 4 columns]

# %%
# Tiempo de duración de los viajes en los sábados lluviosos

duration_rainy_saturday_trips = rainy_saturday_trips['duration_seconds']

duration_rainy_saturday_trips
# Out:
# 6       2969.0
# 30      1980.0
# 34      2460.0
# 51      2760.0
# 52      2460.0
#          ...
# 1031    2560.0
# 1032    1908.0
# 1053    2400.0
# 1061    2186.0
# 1067    2834.0
# Name: duration_seconds, Length: 180, dtype: float64

# %%
# Tiempo de duración de los viajes en los sábados no lluviosos

duration_good_saturday_trips = good_saturday_trips['duration_seconds']

duration_good_saturday_trips
# Out:
# 0       2410.0
# 1       1920.0
# 2       1543.0
# 3       2512.0
# 4       1440.0
#          ...
# 1062    1500.0
# 1063       0.0
# 1064    1318.0
# 1065    2100.0
# 1066    1380.0
# Name: duration_seconds, Length: 888, dtype: float64

# %% [markdown]
# #### **5.5. Prueba de Hipótesis**

# %% [markdown]
# ##### 5.5.1. Prueba de hipótesis

# %% [markdown]
# La hipótesisis que plantea este proyecto es una Hipótesis alternativa, H1: "La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos", debido a que hace referencia a que hay cambios en la duración del los viajes en los días llluviosos.
#
# Por lo tanto palenteo como Hipótesis nula, Ho: "La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare no cambia los sábados".

# %%
# Utilizara prueba t de Students para la prueba de la hipótesis nula Ho

alpha = 0.05

results = st.ttest_ind(duration_rainy_saturday_trips, duration_good_saturday_trips)

print('valor_p:', results.pvalue)

if results.pvalue < alpha:
    print('Rechazar la hipótesis nula, Ho')
else:
    print('No se puede rechazar la hipótesis alternativa, H1')
# Out:
# valor_p: 6.517970327099473e-12
# Rechazar la hipótesis nula, Ho

# %% [markdown]
# ##### 5.5.2. Cálculo de la media y la varianza de la duración de los viajes de los sábados lluviosos

# %%
# Promedio de tiempos sabados lluviosos

mean_rainy_saturday_trips = rainy_saturday_trips['duration_seconds'].mean()
mean_rainy_saturday_trips
# Out:
# 2427.2055555555557

# %%
# calculo de la varianza tiempo de viaje sabados lluviosos

varinaza_rainy_saturday_trips = np.var(duration_rainy_saturday_trips)
varinaza_rainy_saturday_trips
# Out:
# 517403.56330246915

# %% [markdown]
# ##### 5.5.3. Cálculo de la media y la varianza para la duración de los viajes de los sábados no lluviosos

# %%
# Promedio de tiempos sabados no  lluviosos

mean_good_saturday_trips = good_saturday_trips['duration_seconds'].mean()
mean_good_saturday_trips
# Out:
# 1999.6756756756756

# %%
# calculo de la varianza tiempo de viaje sabados no lluviosos

varinaza_good_saturday_trips = np.var(duration_good_saturday_trips)
varinaza_good_saturday_trips
# Out:
# 575732.9308497686

# %% [markdown]
# ##### **Conclusiones de la prueba de Hipótesis**

# %% [markdown]
# Utilicé la prueba t de Student para medias debido a que los datos de la duración de los viajes de los sábados lluviosos y los datos de la duración de los viajes de los sábados no lluviosos son dos muestras independientes. Estos datos no están relacionados entre sí, por lo tanto, se pueden comparar las medias de estas dos muestras para saber si hay diferencia ente ellas.
#
# En cuanto al nivel de significación, decidí establecerlo en alpha = 0.05, debido a que es un valor aplicado en muchos campos de análisis estadísticos y significa la probabilidad cometer un error del 5%, como el rechazar la Hipótesis nula, Ho cuando en verdad puede ser verdadera.
#
# El valor p obtenido en la prueba de Hipótesis es de 6.517970327099473e-12, es un valor muy pequeño y mucho menor a alpha. Por lo tanto, la Hipótesis nula, Ho, en donde se asume que no hay cambios en los tiempos de duración de los viajes de Lopp al Aeropuerto Internacional O'Hare los sábados lluviosos y los no lluviosos se rechaza.
#
# Esto significa que la duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare sí cambia los sábados lluviosos. El resultado es estadísticamente significativo. Esto sugiere que las condiciones climáticas de lluvia en un sábado tienen un impacto en el tiempo que tardan los viajes en ese trayecto.
#
#
# Para confirmar el resultados de la Hipótesis, decidí calcular los valores de la media y la varianza para los días lluviosos y los días no lluviosos
#
# La duración promedio de los viajes los sábados lluviosos (2427.20 segundos) es significativamente mayor a la duración promedio de los viajes los sábados no lluviosos (1999.67 segundos), la diferencia entre estos dos tiempos promedio es de 427.53 segundos o 7,12 minutos por viaje en promedio de más para los días lluviosos.
#
# Las varianzas, 517403.56 para los sábados lluviosos y 575723.93 para los sábados no lluviosos son relativamente similares y muestran una dispersión considerable en la duración de los viajes en ambos grupos. Esto puede deberse a que la duración de los viajes puede variar por factores como el tráfico, ruta exacta, imprevistos en la vía, paradas, entre otros. El hecho de que sean parecidas apoya el uso de la prueba t.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Constanza aplicaste correctamente la prueba de hipótesis comparando la distribución de dos muestras independientes e interpretando de manera acertada el `p-value` obtenido y su relación con la hipótesis nula, logrando comprobar que el clima sí afecta la duración de los viajes en Taxi
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Te recomiendo realizar previamente una prueba de [Levene](https://www.educaopen.com/digital-lab/blog/educacion-digital/prueba-de-levene) para evaluar la igualdad de las varianzas, lo que te permitirá configurar adecuadamente el parámetro **equal_var** en la función `ttest_ind`. Esto te brindará una interpretación más precisa de los resultados además garantizará que la *prueba t* sea estadísticamente válida.
#
# </div>
# </div>
